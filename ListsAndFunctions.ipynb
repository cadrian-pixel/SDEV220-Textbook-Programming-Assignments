# %%
things = ["mozzarella", "cinderella", "salmonella"]
things[1] = things[1].capitalize()
print(things)
things[0] = things[0].upper()
print(things)
del things[2]
print(things)
def good():
    return ["Harry", "Ron", "Hermione"]
def get_odds(val):
    odd = 1
    while odd < val:
        if odd % 2 == 1:
            yield odd
        odd = odd + 1
for int in get_odds(10):
    if int == 5:
        print(int)
